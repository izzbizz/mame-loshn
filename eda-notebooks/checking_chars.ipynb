# %%
from collections import Counter
import unicodedata
import pandas
import re
from prettytable import PrettyTable

import pandas as pd

# %%
brandeis_df = pd.read_excel('data/dataYiddish/brandeis/Yiddish titles export.xlsx')
brandeis_df.head()
# Out:
#                                                title  \
# 0                                         אלבאטראס.
# 1                      אלע ווערק / פון דוד פרישמאן.
# 2  עלון המורה : כלי מבטא של מורי תנועת ״השומר הצע...
# 3           אמאל אין א האלבן יובל / יוסף מענדעלסאן.
# 4        אמאל אין א יובל : זאמלבוך פאר בעלעטריסטיק.
#
#                                                trans
# 0                                          Albaṭros.
# 1                     Ale ṿerḳ / fun Daṿid Frishman.
# 2  Alon ha-moreh : Keli mivṭa shel more tenuʻot ʻ...
# 3           Amol in a halbn yoyvl / Yosef Mendelson.
# 4        Amol in a yoyvl : zamlbukh far beleṭrisṭiḳ.

# %%
# converting to the columns to lists for easier operations

heb_titles = list(brandeis_df['title'])
trnscrpt_titles = list(brandeis_df['trans'])

# %%
with open('data/dataYiddish/hebis/json_parallels.txt') as f:
    text = f.read()
pairs = re.findall('\["(.+?)", "(.+?)"\]', text)
heb_titles += [pair[1] for pair in pairs]
trnscrpt_titles += [pair[0] for pair in pairs]

# %%
df = pd.read_csv('data/dataYiddish/names/names.csv')
heb_titles += list(df.yiddish)
trnscrpt_titles += list(df.english)

# %%
df = pd.read_excel('data/dataYiddish/nli/potsdam1.xlsx', header=None, names=['id', 'title', 'trans'])
df['title_'] = df.title.apply(lambda x: re.sub('\$\$[a-z]', '', x))
df['trans_'] = df.trans.apply(lambda x: re.sub('\$\$[a-z]', '', x))
heb_titles += list(df.title_)
trnscrpt_titles += list(df.trans_)

# %%
df = pd.read_csv('data/dataYiddish/nouns/multi_orthography_parallel_corpus_of_yiddish_nouns.csv')
heb_titles += list(df.yivo)
trnscrpt_titles += list(df.romanized)

# %%
df = pd.read_csv('data/dataYiddish/proverbs/yiddish-wit.csv')
heb_titles += list(df.yiddish)
trnscrpt_titles += list(df.transliteration)

# %%
df = pd.read_csv('data/dataYiddish/refoyl/wordlist.csv')
heb_titles += list(df.Yiddish)
trnscrpt_titles += list(df.Romanized)

# %%
df = pd.read_csv('data/dataYiddish/songtexts/lider-verter.csv')
heb_titles += list(df.yiddish)
trnscrpt_titles += list(df.transliteration)

# %%
df = pd.read_csv('data/dataYiddish/ybc/all-titles-ybc.csv')
heb_titles += list(df.title)
heb_titles += list(df.author)
trnscrpt_titles += list(df['title-trans'])
trnscrpt_titles += list(df['author-trans'])

# %%
with open('data/dataYiddish/yiddishland/yiddishland') as f:
    lines = f.readlines()[3:]
triplets = [line.split() for line in lines if len(line.split()) == 3]
heb_titles += [line[2] for line in triplets]
trnscrpt_titles += [line[0] for line in triplets]

# %%
# collecting two lists of chars for both lists/columns/"languages", seeing to it they are strings

clean_heb_titles = [title for title in heb_titles if isinstance(title, str)]
clean_trnscrpt_titles = [title for title in trnscrpt_titles if isinstance(title, str)]

# %%
# sorting chars by freqs 

heb_chr_freqs = Counter([c for title in clean_heb_titles for c in title]).most_common()
trnscrpt_chr_freqs = Counter([c for title in clean_trnscrpt_titles for c in title]).most_common()

# %%
# a function that prints a nicer table of information, also includes the unicode name for each char

def sort_chars(char_list):
    no_names = []

    table = PrettyTable(['FREQ', 'NAME', 'CHAR'], align='l', min_width=10)
    for c in char_list:
        try: 
            table.add_row([c[1], unicodedata.name(c[0]), c[0]])
        except ValueError:
            no_names.append(c)
    return table, no_names

# %%
# maybe check where these are coming from 

heb_table, heb_no_names = sort_chars(heb_chr_freqs)
heb_no_names
# Out:
# [('\n', 3)]

# %%
# look down the table, there are many non-heb characters. Is it encoding issues or part of the trnscprt system? Just noise?

print(heb_table)
# Out:
# +------------+---------------------------------------+------------+
# | FREQ       | NAME                                  | CHAR       |
# +------------+---------------------------------------+------------+
# | 294141     | HEBREW LETTER AYIN                    | ע          |
# | 261698     | HEBREW LETTER YOD                     | י          |
# | 243039     | HEBREW LETTER ALEF                    | א          |
# | 221995     | SPACE                                 |            |
# | 206412     | HEBREW LETTER RESH                    | ר          |
# | 146437     | HEBREW LETTER VAV                     | ו          |
# | 135459     | HEBREW LETTER NUN                     | נ          |
# | 133408     | HEBREW LETTER TET                     | ט          |
# | 109306     | HEBREW LETTER LAMED                   | ל          |
# | 107155     | HEBREW LETTER QOF                     | ק          |
# | 104178     | HEBREW LETTER DALET                   | ד          |
# | 100063     | HEBREW LETTER FINAL NUN               | ן          |
# | 94336      | HEBREW LETTER PE                      | פ          |
# | 80127      | HEBREW LETTER SAMEKH                  | ס          |
# | 75304      | HEBREW LETTER GIMEL                   | ג          |
# | 75275      | HEBREW LETTER SHIN                    | ש          |
# | 73543      | HEBREW POINT PATAH                    | ַ           |
# | 61098      | HEBREW LETTER MEM                     | מ          |
# | 59361      | HEBREW LETTER BET                     | ב          |
# | 38874      | HEBREW POINT QAMATS                   | ָ           |
# | 37071      | HEBREW LETTER TSADI                   | צ          |
# | 31194      | HEBREW LETTER ZAYIN                   | ז          |
# | 28368      | HEBREW LETTER HE                      | ה          |
# | 28323      | HEBREW POINT RAFE                     | ֿ           |
# | 25808      | HEBREW LETTER KAF                     | כ          |
# | 25710      | FULL STOP                             | .          |
# | 25105      | HEBREW POINT DAGESH OR MAPIQ          | ּ           |
# | 23485      | HEBREW LIGATURE YIDDISH DOUBLE YOD    | ײ          |
# | 19855      | HEBREW LIGATURE YIDDISH DOUBLE VAV    | װ          |
# | 17261      | HEBREW LIGATURE YIDDISH VAV YOD       | ױ          |
# | 16341      | COMMA                                 | ,          |
# | 14612      | HEBREW LETTER FINAL MEM               | ם          |
# | 14137      | COLON                                 | :          |
# | 10881      | SOLIDUS                               | /          |
# | 8649       | HYPHEN-MINUS                          | -          |
# | 8539       | HEBREW LETTER TAV                     | ת          |
# | 7699       | HEBREW LETTER HET                     | ח          |
# | 7265       | HEBREW LETTER FINAL KAF               | ך          |
# | 7028       | DIGIT ONE                             | 1          |
# | 5192       | DIGIT NINE                            | 9          |
# | 3524       | SEMICOLON                             | ;          |
# | 3232       | DIGIT EIGHT                           | 8          |
# | 3221       | HEBREW LETTER FINAL TSADI             | ץ          |
# | 3164       | HEBREW LETTER FINAL PE                | ף          |
# | 2785       | HEBREW PUNCTUATION MAQAF              | ־          |
# | 2285       | APOSTROPHE                            | '          |
# | 2048       | DIGIT ZERO                            | 0          |
# | 1954       | LEFT PARENTHESIS                      | (          |
# | 1946       | RIGHT PARENTHESIS                     | )          |
# | 1882       | HEBREW POINT HIRIQ                    | ִ           |
# | 1797       | DIGIT THREE                           | 3          |
# | 1770       | AMPERSAND                             | &          |
# | 1480       | DIGIT FIVE                            | 5          |
# | 1454       | LATIN SMALL LETTER T                  | t          |
# | 1417       | DIGIT FOUR                            | 4          |
# | 1416       | DIGIT SIX                             | 6          |
# | 1334       | LATIN SMALL LETTER A                  | a          |
# | 1297       | DIGIT TWO                             | 2          |
# | 1200       | DIGIT SEVEN                           | 7          |
# | 1164       | EQUALS SIGN                           | =          |
# | 1099       | LATIN SMALL LETTER L                  | l          |
# | 1084       | LATIN SMALL LETTER D                  | d          |
# | 1057       | QUOTATION MARK                        | "          |
# | 947        | LEFT SQUARE BRACKET                   | [          |
# | 940        | RIGHT SQUARE BRACKET                  | ]          |
# | 842        | LATIN SMALL LETTER O                  | o          |
# | 648        | LATIN SMALL LETTER E                  | e          |
# | 562        | LATIN SMALL LETTER I                  | i          |
# | 561        | NUMBER SIGN                           | #          |
# | 532        | QUESTION MARK                         | ?          |
# | 485        | LATIN SMALL LETTER R                  | r          |
# | 464        | HEBREW PUNCTUATION GERSHAYIM          | ״          |
# | 461        | LATIN SMALL LETTER U                  | u          |
# | 411        | COMMERCIAL AT                         | @          |
# | 403        | LATIN SMALL LETTER N                  | n          |
# | 402        | LATIN SMALL LETTER S                  | s          |
# | 341        | LATIN SMALL LETTER Q                  | q          |
# | 320        | LATIN SMALL LETTER H                  | h          |
# | 298        | HEBREW PUNCTUATION GERESH             | ׳          |
# | 248        | RIGHT-TO-LEFT MARK                    | ‏           |
# | 205        | LOW LINE                              | _          |
# | 201        | LATIN SMALL LETTER C                  | c          |
# | 190        | LATIN SMALL LETTER M                  | m          |
# | 165        | REVERSE SOLIDUS                       | \          |
# | 159        | LATIN SMALL LETTER P                  | p          |
# | 141        | LATIN SMALL LETTER B                  | b          |
# | 136        | EXCLAMATION MARK                      | !          |
# | 132        | HEBREW POINT SIN DOT                  | ׂ           |
# | 128        | LATIN CAPITAL LETTER I                | I          |
# | 108        | LATIN SMALL LETTER Y                  | y          |
# | 106        | LATIN SMALL LETTER G                  | g          |
# | 104        | LATIN SMALL LETTER F                  | f          |
# | 93         | LATIN CAPITAL LETTER J                | J          |
# | 81         | LEFT CURLY BRACKET                    | {          |
# | 80         | LESS-THAN SIGN                        | <          |
# | 80         | RIGHT CURLY BRACKET                   | }          |
# | 69         | LATIN SMALL LETTER K                  | k          |
# | 63         | LATIN SMALL LETTER W                  | w          |
# | 58         | LATIN SMALL LETTER V                  | v          |
# | 56         | LATIN CAPITAL LETTER X                | X          |
# | 52         | LATIN CAPITAL LETTER E                | E          |
# | 48         | LATIN CAPITAL LETTER S                | S          |
# | 43         | LATIN CAPITAL LETTER T                | T          |
# | 37         | LATIN CAPITAL LETTER V                | V          |
# | 37         | LATIN SMALL LETTER Z                  | z          |
# | 36         | LATIN CAPITAL LETTER Y                | Y          |
# | 35         | LATIN CAPITAL LETTER A                | A          |
# | 35         | RIGHT SINGLE QUOTATION MARK           | ’          |
# | 34         | HEBREW LETTER ALEF WITH PATAH         | אַ          |
# | 33         | LATIN CAPITAL LETTER D                | D          |
# | 32         | LATIN CAPITAL LETTER H                | H          |
# | 29         | HEBREW LETTER PE WITH RAFE            | פֿ          |
# | 27         | EN DASH                               | –          |
# | 24         | LATIN CAPITAL LETTER B                | B          |
# | 24         | LATIN SMALL LETTER X                  | x          |
# | 23         | LATIN CAPITAL LETTER L                | L          |
# | 21         | LATIN CAPITAL LETTER C                | C          |
# | 21         | HEBREW LETTER ALEF WITH QAMATS        | אָ          |
# | 20         | LATIN CAPITAL LETTER N                | N          |
# | 20         | LATIN CAPITAL LETTER P                | P          |
# | 19         | LATIN CAPITAL LETTER M                | M          |
# | 18         | MODIFIER LETTER PRIME                 | ʹ          |
# | 17         | DOUBLE PRIME                          | ″          |
# | 16         | LATIN CAPITAL LETTER W                | W          |
# | 14         | LATIN CAPITAL LETTER F                | F          |
# | 14         | LATIN CAPITAL LETTER G                | G          |
# | 14         | LEFT-TO-RIGHT MARK                    | ‎           |
# | 13         | GREATER-THAN SIGN                     | >          |
# | 12         | LATIN CAPITAL LETTER K                | K          |
# | 12         | LATIN CAPITAL LETTER R                | R          |
# | 11         | POP DIRECTIONAL FORMATTING            | ‬           |
# | 11         | HEBREW LETTER PE WITH DAGESH          | פּ          |
# | 10         | LATIN CAPITAL LETTER O                | O          |
# | 9          | WHITE SQUARE                          | □          |
# | 9          | HEBREW POINT QUBUTS                   | ֻ           |
# | 8          | HEBREW PUNCTUATION SOF PASUQ          | ׃          |
# | 7          | LATIN CAPITAL LETTER U                | U          |
# | 7          | LATIN SMALL LETTER A WITH DIAERESIS   | ä          |
# | 6          | LATIN SMALL LETTER E WITH ACUTE       | é          |
# | 6          | HEBREW LIGATURE YIDDISH YOD YOD PATAH | ײַ          |
# | 5          | HEBREW POINT SEGOL                    | ֶ           |
# | 5          | LATIN CAPITAL LETTER Z                | Z          |
# | 5          | LATIN SMALL LETTER J                  | j          |
# | 5          | RIGHT-TO-LEFT EMBEDDING               | ‫           |
# | 4          | LATIN CAPITAL LETTER Q                | Q          |
# | 4          | LATIN SMALL LETTER I WITH BREVE       | ĭ          |
# | 4          | LATIN SMALL LETTER I WITH MACRON      | ī          |
# | 4          | MODIFIER LETTER RIGHT HALF RING       | ʾ          |
# | 3          | LATIN SMALL LETTER I WITH ACUTE       | í          |
# | 3          | LATIN SMALL LETTER A WITH ACUTE       | á          |
# | 3          | LEFT-TO-RIGHT EMBEDDING               | ‪           |
# | 3          | CYRILLIC SMALL LETTER A               | а          |
# | 3          | CYRILLIC SMALL LETTER O               | о          |
# | 3          | CYRILLIC SMALL LETTER I               | и          |
# | 3          | COMBINING DOT BELOW                   | ̣           |
# | 3          | DOLLAR SIGN                           | $          |
# | 3          | EM DASH                               | —          |
# | 3          | HEBREW LETTER BET WITH RAFE           | בֿ          |
# | 2          | LATIN SMALL LETTER C WITH CEDILLA     | ç          |
# | 2          | CYRILLIC SMALL LETTER ER              | р          |
# | 2          | CYRILLIC SMALL LETTER IE              | е          |
# | 2          | CYRILLIC SMALL LETTER EL              | л          |
# | 2          | CYRILLIC SMALL LETTER ES              | с          |
# | 2          | COMBINING GRAVE ACCENT                | ̀           |
# | 2          | COMBINING MACRON BELOW                | ̱           |
# | 2          | PERCENT SIGN                          | %          |
# | 2          | LATIN SMALL LETTER U WITH DIAERESIS   | ü          |
# | 2          | HEBREW LETTER KAF WITH DAGESH         | כּ          |
# | 2          | HEBREW LETTER TAV WITH DAGESH         | תּ          |
# | 2          | MODIFIER LETTER APOSTROPHE            | ʼ          |
# | 2          | COMBINING RING ABOVE                  | ̊           |
# | 2          | LATIN SMALL LETTER N WITH TILDE       | ñ          |
# | 1          | LATIN SMALL LETTER U WITH ACUTE       | ú          |
# | 1          | COMBINING ACUTE ACCENT                | ́           |
# | 1          | CYRILLIC CAPITAL LETTER EF            | Ф          |
# | 1          | CYRILLIC SMALL LETTER ZE              | з          |
# | 1          | CYRILLIC SMALL LETTER GHE             | г          |
# | 1          | CYRILLIC SMALL LETTER CHE             | ч          |
# | 1          | CYRILLIC SMALL LETTER KA              | к          |
# | 1          | CYRILLIC SMALL LETTER SHORT I         | й          |
# | 1          | CYRILLIC SMALL LETTER VE              | в          |
# | 1          | CYRILLIC SMALL LETTER SOFT SIGN       | ь          |
# | 1          | CYRILLIC CAPITAL LETTER I             | И          |
# | 1          | CYRILLIC SMALL LETTER DE              | д          |
# | 1          | CYRILLIC SMALL LETTER SHA             | ш          |
# | 1          | LATIN LETTER ALVEOLAR CLICK           | ǂ          |
# | 1          | LATIN CAPITAL LETTER V WITH DOT BELOW | Ṿ          |
# | 1          | LATIN SMALL LETTER A WITH TILDE       | ã          |
# | 1          | MODIFIER LETTER TURNED COMMA          | ʻ          |
# | 1          | LATIN SMALL LETTER E WITH CIRCUMFLEX  | ê          |
# | 1          | LATIN SMALL LETTER E WITH DOT ABOVE   | ė          |
# | 1          | HEBREW POINT METEG                    | ֽ           |
# | 1          | COMBINING CARON                       | ̌           |
# | 1          | LATIN SMALL LETTER SHARP S            | ß          |
# | 1          | HEBREW POINT HOLAM                    | ֹ           |
# | 1          | HEBREW LETTER YOD WITH HIRIQ          | יִ          |
# | 1          | HEBREW POINT SHIN DOT                 | ׁ           |
# | 1          | HEBREW LETTER VAV WITH DAGESH         | וּ          |
# | 1          | LATIN SMALL LETTER O WITH DIAERESIS   | ö          |
# | 1          | DOUBLE ACUTE ACCENT                   | ˝          |
# | 1          | NO-BREAK SPACE                        |            |
# +------------+---------------------------------------+------------+

# %%
# looks cleaner 

trnscrpt_table, trnscrpt_no_names = sort_chars(trnscrpt_chr_freqs)
trnscrpt_no_names
# Out:
# [('\n', 1), ('\x7f', 1)]

# %%
# a long tails of disturbing chars. Noise? 

print(trnscrpt_table)
# Out:
# +------------+----------------------------------------+------------+
# | FREQ       | NAME                                   | CHAR       |
# +------------+----------------------------------------+------------+
# | 341115     | LATIN SMALL LETTER E                   | e          |
# | 229626     | LATIN SMALL LETTER N                   | n          |
# | 207855     | SPACE                                  |            |
# | 200683     | LATIN SMALL LETTER R                   | r          |
# | 183370     | LATIN SMALL LETTER I                   | i          |
# | 181048     | LATIN SMALL LETTER S                   | s          |
# | 159496     | LATIN SMALL LETTER A                   | a          |
# | 142730     | LATIN SMALL LETTER T                   | t          |
# | 123145     | LATIN SMALL LETTER H                   | h          |
# | 116486     | LATIN SMALL LETTER K                   | k          |
# | 113045     | LATIN SMALL LETTER O                   | o          |
# | 103332     | LATIN SMALL LETTER L                   | l          |
# | 96069      | LATIN SMALL LETTER D                   | d          |
# | 88326      | LATIN SMALL LETTER Y                   | y          |
# | 83012      | LATIN SMALL LETTER U                   | u          |
# | 70299      | LATIN SMALL LETTER G                   | g          |
# | 64616      | LATIN SMALL LETTER M                   | m          |
# | 56123      | LATIN SMALL LETTER F                   | f          |
# | 47023      | LATIN SMALL LETTER B                   | b          |
# | 31840      | LATIN SMALL LETTER P                   | p          |
# | 30094      | LATIN SMALL LETTER V                   | v          |
# | 28340      | LATIN SMALL LETTER Z                   | z          |
# | 28101      | LATIN SMALL LETTER T WITH DOT BELOW    | ṭ          |
# | 24443      | COMMA                                  | ,          |
# | 23150      | COMBINING DOT BELOW                    | ̣           |
# | 20344      | DIGIT ONE                              | 1          |
# | 20100      | HYPHEN-MINUS                           | -          |
# | 19309      | FULL STOP                              | .          |
# | 14620      | LATIN SMALL LETTER K WITH DOT BELOW    | ḳ          |
# | 13565      | DIGIT NINE                             | 9          |
# | 11045      | DIGIT EIGHT                            | 8          |
# | 10643      | LATIN CAPITAL LETTER S                 | S          |
# | 9651       | SOLIDUS                                | /          |
# | 9485       | LATIN CAPITAL LETTER A                 | A          |
# | 9387       | LATIN CAPITAL LETTER D                 | D          |
# | 9078       | LATIN CAPITAL LETTER Y                 | Y          |
# | 8960       | LATIN SMALL LETTER V WITH DOT BELOW    | ṿ          |
# | 8849       | LATIN CAPITAL LETTER M                 | M          |
# | 6662       | LATIN CAPITAL LETTER I                 | I          |
# | 6455       | COLON                                  | :          |
# | 5924       | LATIN CAPITAL LETTER B                 | B          |
# | 5754       | LATIN CAPITAL LETTER L                 | L          |
# | 5635       | LATIN CAPITAL LETTER E                 | E          |
# | 5117       | LATIN SMALL LETTER C                   | c          |
# | 4812       | LATIN CAPITAL LETTER T                 | T          |
# | 4670       | LATIN CAPITAL LETTER R                 | R          |
# | 4606       | LATIN CAPITAL LETTER G                 | G          |
# | 4460       | DIGIT FIVE                             | 5          |
# | 4016       | DIGIT ZERO                             | 0          |
# | 3969       | DIGIT SIX                              | 6          |
# | 3898       | LATIN CAPITAL LETTER P                 | P          |
# | 3847       | LATIN CAPITAL LETTER K                 | K          |
# | 3729       | LATIN CAPITAL LETTER F                 | F          |
# | 3692       | LATIN CAPITAL LETTER H                 | H          |
# | 3692       | LATIN CAPITAL LETTER N                 | N          |
# | 3484       | DIGIT SEVEN                            | 7          |
# | 3425       | DIGIT FOUR                             | 4          |
# | 3380       | DIGIT THREE                            | 3          |
# | 3078       | LATIN CAPITAL LETTER O                 | O          |
# | 3023       | DIGIT TWO                              | 2          |
# | 2773       | LATIN SMALL LETTER H WITH DOT BELOW    | ḥ          |
# | 2666       | LATIN CAPITAL LETTER Z                 | Z          |
# | 2666       | COMBINING GRAVE ACCENT                 | ̀           |
# | 2087       | LATIN CAPITAL LETTER V                 | V          |
# | 2061       | SEMICOLON                              | ;          |
# | 1798       | APOSTROPHE                             | '          |
# | 1715       | LATIN CAPITAL LETTER J                 | J          |
# | 1676       | LATIN CAPITAL LETTER K WITH DOT BELOW  | Ḳ          |
# | 1611       | LATIN SMALL LETTER W                   | w          |
# | 1561       | LATIN CAPITAL LETTER V WITH DOT BELOW  | Ṿ          |
# | 1433       | AMPERSAND                              | &          |
# | 1339       | EQUALS SIGN                            | =          |
# | 1259       | LATIN SMALL LETTER S WITH ACUTE        | ś          |
# | 1197       | LATIN CAPITAL LETTER U                 | U          |
# | 1145       | MODIFIER LETTER RIGHT HALF RING        | ʾ          |
# | 1001       | LATIN CAPITAL LETTER H WITH DOT BELOW  | Ḥ          |
# | 1000       | LEFT SQUARE BRACKET                    | [          |
# | 999        | RIGHT SQUARE BRACKET                   | ]          |
# | 906        | RIGHT PARENTHESIS                      | )          |
# | 905        | MODIFIER LETTER LEFT HALF RING         | ʿ          |
# | 896        | LEFT PARENTHESIS                       | (          |
# | 827        | LATIN CAPITAL LETTER C                 | C          |
# | 795        | QUESTION MARK                          | ?          |
# | 762        | LATIN CAPITAL LETTER T WITH DOT BELOW  | Ṭ          |
# | 701        | LATIN CAPITAL LETTER W                 | W          |
# | 638        | MODIFIER LETTER TURNED COMMA           | ʻ          |
# | 617        | NUMBER SIGN                            | #          |
# | 598        | LOW LINE                               | _          |
# | 500        | COMMERCIAL AT                          | @          |
# | 486        | QUOTATION MARK                         | "          |
# | 449        | COMBINING ACUTE ACCENT                 | ́           |
# | 444        | LATIN SMALL LETTER S WITH CARON        | š          |
# | 435        | MODIFIER LETTER APOSTROPHE             | ʼ          |
# | 375        | LATIN SMALL LETTER J                   | j          |
# | 248        | LATIN SMALL LETTER Q                   | q          |
# | 232        | LATIN SMALL LETTER X                   | x          |
# | 205        | LATIN SMALL LETTER A WITH MACRON       | ā          |
# | 203        | MODIFIER LETTER PRIME                  | ʹ          |
# | 192        | LATIN SMALL LETTER I WITH CIRCUMFLEX   | î          |
# | 150        | REVERSE SOLIDUS                        | \          |
# | 145        | EXCLAMATION MARK                       | !          |
# | 144        | LATIN SMALL LETTER O WITH CIRCUMFLEX   | ô          |
# | 126        | LATIN SMALL LETTER I WITH BREVE        | ĭ          |
# | 111        | LATIN CAPITAL LETTER S WITH CARON      | Š          |
# | 110        | LATIN SMALL LETTER U WITH CIRCUMFLEX   | û          |
# | 97         | LATIN SMALL LETTER E WITH MACRON       | ē          |
# | 95         | LEFT CURLY BRACKET                     | {          |
# | 82         | LATIN SMALL LETTER E WITH ACUTE        | é          |
# | 80         | RIGHT CURLY BRACKET                    | }          |
# | 76         | HEBREW LETTER AYIN                     | ע          |
# | 64         | HEBREW LETTER YOD                      | י          |
# | 64         | HEBREW LETTER ALEF                     | א          |
# | 59         | HEBREW LETTER VAV                      | ו          |
# | 53         | HEBREW LETTER RESH                     | ר          |
# | 52         | LATIN CAPITAL LETTER X                 | X          |
# | 48         | LATIN SMALL LETTER S WITH DOT BELOW    | ṣ          |
# | 47         | LATIN SMALL LETTER L WITH STROKE       | ł          |
# | 44         | LATIN CAPITAL LETTER S WITH ACUTE      | Ś          |
# | 44         | LATIN SMALL LETTER U WITH DIAERESIS    | ü          |
# | 42         | LATIN SMALL LETTER O WITH ACUTE        | ó          |
# | 39         | COMBINING MACRON BELOW                 | ̱           |
# | 38         | HEBREW LETTER NUN                      | נ          |
# | 33         | LATIN SMALL LETTER E WITH CIRCUMFLEX   | ê          |
# | 32         | LATIN CAPITAL LETTER Q                 | Q          |
# | 31         | LATIN SMALL LETTER E WITH GRAVE        | è          |
# | 31         | HEBREW LETTER FINAL NUN                | ן          |
# | 27         | LATIN SMALL LETTER O WITH DIAERESIS    | ö          |
# | 24         | LATIN SMALL LETTER K WITH LINE BELOW   | ḵ          |
# | 23         | HEBREW LETTER TET                      | ט          |
# | 23         | HEBREW LETTER LAMED                    | ל          |
# | 23         | LATIN SMALL LETTER A WITH DIAERESIS    | ä          |
# | 22         | HEBREW LETTER GIMEL                    | ג          |
# | 21         | HEBREW LETTER DALET                    | ד          |
# | 19         | HEBREW LETTER MEM                      | מ          |
# | 19         | HEBREW LETTER QOF                      | ק          |
# | 18         | GRAVE ACCENT                           | `          |
# | 17         | COMBINING LIGATURE RIGHT HALF          | ︡           |
# | 17         | HEBREW LETTER PE                       | פ          |
# | 15         | COMBINING LIGATURE LEFT HALF           | ︠           |
# | 15         | LATIN SMALL LETTER A WITH ACUTE        | á          |
# | 14         | LATIN SMALL LETTER Z WITH DOT BELOW    | ẓ          |
# | 14         | HEBREW LETTER BET                      | ב          |
# | 13         | LATIN SMALL LETTER I WITH ACUTE        | í          |
# | 13         | LATIN CAPITAL LETTER E WITH DOT ABOVE  | Ė          |
# | 12         | HEBREW LETTER SAMEKH                   | ס          |
# | 11         | LATIN SMALL LETTER I WITH MACRON       | ī          |
# | 11         | HEBREW LETTER SHIN                     | ש          |
# | 11         | LATIN SMALL LETTER E WITH BREVE        | ĕ          |
# | 11         | LATIN SMALL LETTER C WITH CARON        | č          |
# | 10         | LATIN SMALL LETTER A WITH CIRCUMFLEX   | â          |
# | 10         | LATIN SMALL LETTER O WITH MACRON       | ō          |
# | 9          | LATIN CAPITAL LETTER A WITH MACRON     | Ā          |
# | 9          | HEBREW LETTER ZAYIN                    | ז          |
# | 9          | LATIN SMALL LETTER N WITH TILDE        | ñ          |
# | 8          | LATIN SMALL LETTER E WITH DOT BELOW    | ẹ          |
# | 8          | COMBINING BREVE                        | ̆           |
# | 8          | LATIN SMALL LETTER U WITH DOT BELOW    | ụ          |
# | 8          | HEBREW LETTER TSADI                    | צ          |
# | 7          | LATIN SMALL LETTER I WITH DOT BELOW    | ị          |
# | 7          | HEBREW LETTER HE                       | ה          |
# | 6          | LATIN SMALL LETTER Z WITH DOT ABOVE    | ż          |
# | 6          | LATIN SMALL LETTER N WITH ACUTE        | ń          |
# | 6          | COMBINING DOT ABOVE                    | ̇           |
# | 6          | LATIN SMALL LETTER E WITH DOT ABOVE    | ė          |
# | 6          | LATIN CAPITAL LETTER O WITH CIRCUMFLEX | Ô          |
# | 6          | LATIN CAPITAL LETTER S WITH DOT BELOW  | Ṣ          |
# | 6          | HEBREW LETTER KAF                      | כ          |
# | 5          | COMBINING DOUBLE INVERTED BREVE        | ͡           |
# | 5          | LATIN SMALL LETTER C WITH CEDILLA      | ç          |
# | 5          | LATIN SMALL LETTER R WITH DOT BELOW    | ṛ          |
# | 5          | LATIN SMALL LETTER A WITH DOT BELOW    | ạ          |
# | 5          | LATIN SMALL LETTER D WITH DOT BELOW    | ḍ          |
# | 5          | LATIN SMALL LETTER Z WITH CARON        | ž          |
# | 5          | LATIN SMALL LETTER I WITH DIAERESIS    | ï          |
# | 5          | LESS-THAN SIGN                         | <          |
# | 5          | GREATER-THAN SIGN                      | >          |
# | 4          | MODIFIER LETTER DOUBLE PRIME           | ʺ          |
# | 4          | LATIN SMALL LETTER E WITH OGONEK       | ę          |
# | 4          | LATIN SMALL LETTER I WITH CARON        | ǐ          |
# | 4          | LATIN SMALL LETTER N WITH DOT BELOW    | ṇ          |
# | 4          | LATIN CAPITAL LETTER I WITH CIRCUMFLEX | Î          |
# | 4          | LATIN SMALL LETTER O WITH DOT BELOW    | ọ          |
# | 4          | LATIN CAPITAL LETTER U WITH DIAERESIS  | Ü          |
# | 4          | HEBREW LETTER FINAL KAF                | ך          |
# | 4          | LATIN CAPITAL LETTER Z WITH DOT ABOVE  | Ż          |
# | 4          | LATIN SMALL LETTER O WITH STROKE       | ø          |
# | 3          | LATIN SMALL LETTER U WITH ACUTE        | ú          |
# | 3          | LATIN CAPITAL LETTER L WITH STROKE     | Ł          |
# | 3          | COMBINING DIAERESIS                    | ̈           |
# | 3          | HEBREW PUNCTUATION MAQAF               | ־          |
# | 3          | LATIN SMALL LETTER A WITH OGONEK       | ą          |
# | 3          | LATIN SMALL LETTER U WITH MACRON       | ū          |
# | 3          | COMBINING MACRON                       | ̄           |
# | 3          | COMBINING TILDE                        | ̃           |
# | 3          | EM DASH                                | —          |
# | 3          | HEBREW POINT QAMATS                    | ָ           |
# | 3          | HEBREW LETTER TAV                      | ת          |
# | 3          | HEBREW LETTER FINAL PE                 | ף          |
# | 3          | HEBREW LETTER HET                      | ח          |
# | 2          | LATIN SMALL LETTER R WITH ACUTE        | ŕ          |
# | 2          | LATIN SMALL LETTER W WITH DOT BELOW    | ẉ          |
# | 2          | LATIN CAPITAL LETTER A WITH ACUTE      | Á          |
# | 2          | LATIN CAPITAL LETTER Y WITH DOT BELOW  | Ỵ          |
# | 2          | LATIN CAPITAL LETTER U WITH CIRCUMFLEX | Û          |
# | 2          | DOLLAR SIGN                            | $          |
# | 2          | DOUBLE LOW-9 QUOTATION MARK            | „          |
# | 2          | LEFT DOUBLE QUOTATION MARK             | “          |
# | 2          | ACUTE ACCENT                           | ´          |
# | 2          | LATIN SMALL LETTER E WITH DIAERESIS    | ë          |
# | 2          | DEGREE SIGN                            | °          |
# | 2          | HEBREW POINT RAFE                      | ֿ           |
# | 2          | HEBREW LETTER FINAL TSADI              | ץ          |
# | 1          | LATIN CAPITAL LETTER I WITH MACRON     | Ī          |
# | 1          | COMBINING CANDRABINDU                  | ̐           |
# | 1          | COMBINING CIRCUMFLEX ACCENT            | ̂           |
# | 1          | COMBINING BREVE BELOW                  | ̮           |
# | 1          | COMBINING RING BELOW                   | ̥           |
# | 1          | SCRIPT SMALL L                         | ℓ          |
# | 1          | LATIN SMALL LETTER A WITH TILDE        | ã          |
# | 1          | LATIN SMALL LETTER Y WITH DOT BELOW    | ỵ          |
# | 1          | LATIN SMALL LETTER G WITH DOT ABOVE    | ġ          |
# | 1          | COMBINING LOW LINE                     | ̲           |
# | 1          | LATIN CAPITAL LETTER E WITH CIRCUMFLEX | Ê          |
# | 1          | COMBINING DIAERESIS BELOW              | ̤           |
# | 1          | LATIN SMALL LETTER K WITH CEDILLA      | ķ          |
# | 1          | LATIN SMALL LETTER SHARP S             | ß          |
# | 1          | LATIN SMALL LETTER R WITH CARON        | ř          |
# | 1          | COMBINING CEDILLA                      | ̧           |
# | 1          | LATIN SMALL LIGATURE FL                | ﬂ          |
# | 1          | COMBINING COMMA BELOW                  | ̦           |
# | 1          | HEBREW POINT PATAH                     | ַ           |
# | 1          | LATIN SMALL LETTER E WITH CARON        | ě          |
# | 1          | HEBREW LIGATURE YIDDISH DOUBLE YOD     | ײ          |
# | 1          | HEBREW LETTER FINAL MEM                | ם          |
# | 1          | LATIN SMALL LETTER U WITH GRAVE        | ù          |
# | 1          | PERCENT SIGN                           | %          |
# | 1          | LATIN SMALL LETTER U WITH BREVE        | ŭ          |
# | 1          | RIGHT-TO-LEFT MARK                     | ‏           |
# | 1          | LATIN CAPITAL LETTER E WITH ACUTE      | É          |
# | 1          | LATIN SMALL LETTER A WITH BREVE        | ă          |
# | 1          | LATIN SMALL LETTER S WITH CEDILLA      | ş          |
# +------------+----------------------------------------+------------+

# %%
heb_tokens = [word for title in clean_heb_titles for word in title.split()]
trns_tokens = [word.lower() for title in clean_trnscrpt_titles for word in title.split()]

# %%
Counter(heb_tokens).most_common()
# Out:
# [('פון', 11661),
#  (':', 8670),
#  ('און', 8395),
#  ('דער', 5546),
#  ('אין', 5464),
#  ('די', 4162),
#  ('א', 3621),
#  ('/', 3494),
#  (';', 2488),
#  ('...', 1743),
#  ('לידער', 1440),
#  ('פאר', 1204),
#  ('מיט', 1161),
#  ('/פון', 1121),
#  ('דאס', 991),
#  ('ראמאן', 990),
#  ('-', 959),
#  ('צו', 873),
#  ('געשיכטע', 859),
#  ('לעבן', 819),
#  ('אויף', 778),
#  ('משה', 723),
#  ('דעם', 715),
#  ('יעקב', 715),
#  ('דערציילונגען', 676),
#  ('ווערק', 670),
#  ('מיין', 657),
#  ('יידישע', 655),
#  ('ישראל', 649),
#  ('יצחק', 646),
#  ('י.', 632),
#  ('אברהם', 604),
#  ('יידיש', 580),
#  ('זיין', 579),
#  ('דוד', 540),
#  ('אלע', 537),
#  ('שלום', 526),
#  ('ספר', 513),
#  ('וועגן', 506),
#  ('יידישער', 484),
#  ('יוסף', 475),
#  ('א.', 474),
#  ('בן', 465),
#  ('איז', 447),
#  ('חיים', 443),
#  ('אידישע', 428),
#  ('איבערזעצט', 427),
#  ('בילדער', 416),
#  ('בוך', 413),
#  ('געקליבענע', 407),
#  ('צום', 400),
#  ('אנדערע', 399),
#  (':א', 394),
#  ('וועלט', 389),
#  ('זכרונות', 389),
#  ('שלמה', 387),
#  ('קינדער', 380),
#  ('יאר', 376),
#  ('יידישן', 376),
#  ('מ.', 366),
#  ('יידן', 363),
#  ('דורך', 359),
#  ('דיא', 353),
#  ('ליטעראטור', 350),
#  ('שריפטען', 345),
#  ('ביז', 334),
#  ('י', 316),
#  ('אן', 315),
#  ('לעבען', 314),
#  ('וואס', 305),
#  (':לידער', 302),
#  ('דריי', 295),
#  ('צוויי', 292),
#  ('שריפטן', 287),
#  ('מ', 283),
#  ('עסייען', 282),
#  ('ש.', 281),
#  ('צייט', 280),
#  ('איבער', 274),
#  ('אידישער', 274),
#  ('שמואל', 269),
#  ('פאלק', 263),
#  (':ראמאן', 263),
#  ('אקטען', 258),
#  ('אונ', 257),
#  ('צווישן', 251),
#  ('ב.', 250),
#  ('אידיש', 249),
#  ('ל', 245),
#  ('=', 242),
#  ('ווי', 239),
#  ('פאעמעס', 232),
#  ('זיך', 227),
#  ('אהרן', 226),
#  ('מיינע', 226),
#  ('מאיר', 224),
#  ('אמעריקע', 223),
#  ('מרדכי', 221),
#  ('אונטער', 220),
#  ('צבי', 220),
#  ('וועג', 219),
#  ('געזאמעלטע', 218),
#  ('ביי', 213),
#  ('יהודה', 212),
#  ('[פון]', 211),
#  ('פרץ', 209),
#  ('ל.', 207),
#  ('פונ', 203),
#  ('זאמלונג', 203),
#  ('פוילן', 202),
#  ('יארן', 201),
#  ('פיר', 200),
#  ('ש', 199),
#  ('טעג', 197),
#  ('איך', 197),
#  ('אַ', 196),
#  ('יודישע', 193),
#  ('לייב', 193),
#  ('אויפן', 192),
#  ('נאך', 191),
#  ("מ'", 189),
#  ('נייע', 187),
#  ('תורה', 185),
#  ('שול', 184),
#  ("א'", 184),
#  ('עליכם', 182),
#  ('היים', 180),
#  ('ניט', 180),
#  ('ב', 180),
#  ('מיר', 178),
#  ('4', 177),
#  ('מענטש', 175),
#  ('אונזער', 172),
#  ('פרץ,', 171),
#  ('/יעקב', 171),
#  ('איין', 169),
#  ('אדער,', 164),
#  ('/משה', 164),
#  ('געזאמלטע', 163),
#  ('ערד', 161),
#  ('זלמן', 160),
#  ('שרייבער', 159),
#  ('ליכט', 159),
#  ('געטא', 157),
#  ('זיינע', 157),
#  ('אונדזער', 154),
#  ('ערצעהלונגען', 154),
#  ('קאמף', 152),
#  ('דור', 150),
#  ('אקטן', 149),
#  ('האט', 147),
#  ('נחמן', 146),
#  ('ארבעטער', 146),
#  ('ה.', 145),
#  ('רעדאקציע', 145),
#  ('וועגען', 145),
#  ('ליד', 145),
#  ('פארן', 144),
#  ("י'", 144),
#  ('לאנד', 142),
#  ('ווארט', 141),
#  ('מענטשן', 140),
#  ('ביים', 139),
#  ('רייזע', 138),
#  ('טעאטער', 137),
#  ('ארץ', 135),
#  ('אש,', 133),
#  ('אידישן', 132),
#  ('זון', 129),
#  ('של', 128),
#  ('מענדעלע', 128),
#  ('שמעון', 128),
#  ('מעשה', 128),
#  ('פאעמען', 128),
#  ('טאג', 128),
#  ('נ.', 125),
#  ('ירושלים', 124),
#  ('אליעזר', 124),
#  ('פארווארט', 121),
#  (':דערציילונגען', 121),
#  ('געווען', 120),
#  ('על', 120),
#  ('אדער', 119),
#  ('אזוי', 119),
#  ('ה', 119),
#  ('פאעמע', 118),
#  ('/יצחק', 118),
#  ('הירש', 117),
#  ('אידן', 117),
#  ('געזאנג', 117),
#  ('קולטור', 116),
#  ('ליטערארישע', 115),
#  ('לויט', 115),
#  (':און', 115),
#  ('בלעטער', 114),
#  ('ערשטע', 114),
#  ('דורות', 114),
#  ('/אברהם', 114),
#  ('איבערגעזעצט', 113),
#  ('קיין', 111),
#  ('אידישען', 111),
#  ('פ.', 110),
#  ('נאוועלן', 110),
#  ('ער', 110),
#  ('ז', 110),
#  ("ש'", 110),
#  ('3', 109),
#  ('רוסלאנד', 109),
#  ('עם', 109),
#  ('דראמע', 109),
#  ('חורבן', 108),
#  ('מארק', 107),
#  ('מוכר', 107),
#  ('מלחמה', 107),
#  ('אריינפיר', 107),
#  ('ביאגראפיע', 107),
#  ('שפראך', 106),
#  ('ספרים', 106),
#  ('מעשיות', 106),
#  ('מנחם', 104),
#  ('י.ל', 104),
#  ('היסטארישער', 103),
#  ('רבי', 103),
#  ('/...', 103),
#  ('שטאט', 102),
#  ('לידער,', 102),
#  ('אליהו', 102),
#  ('צייטן', 102),
#  ('בר', 100),
#  ('מען', 100),
#  ('נייער', 100),
#  ('ווארשע', 100),
#  ('פאן', 99),
#  ('ד.', 99),
#  ('/יוסף', 98),
#  (':...', 98),
#  ('ח.', 97),
#  ('רעדאקטירט', 97),
#  ('אשכנז', 97),
#  ('אמאל', 96),
#  ('רעדאגירט', 96),
#  ('ז.', 96),
#  ('דראמא', 96),
#  ('אילוסטרירט', 96),
#  ('איציק', 96),
#  ('טיילן', 95),
#  ('מלך', 94),
#  ('הויז', 93),
#  ('עס', 93),
#  ('לעאן', 92),
#  ('פונעם', 92),
#  ('מענדל', 92),
#  ('פ', 92),
#  ('אלטער', 91),
#  ('ברוך', 91),
#  ('ערשטער', 91),
#  ('דראמאטישע', 91),
#  ('היסטארישע', 91),
#  ('שאפן', 90),
#  ('אריה', 90),
#  ('אמעריקאנער', 89),
#  ('קונסט', 89),
#  ('פראבלעמען', 89),
#  ('ים', 89),
#  ('יאהר', 89),
#  ('יידנטום', 89),
#  ('ליב', 89),
#  ('פינף', 88),
#  ('ארויסגעגעבן', 88),
#  ('בער', 88),
#  ('ליעדער', 86),
#  ('שאול', 86),
#  ('ניו', 86),
#  ('יהושע', 86),
#  ('/צוזאמענגעשטעלט', 86),
#  ('/דוד', 86),
#  (':אין', 86),
#  ('אינ', 85),
#  ('אלכסנדר', 85),
#  ('יארהונדערט', 85),
#  ('בריוו', 85),
#  ('באוועגונג', 85),
#  ('לעצטע', 84),
#  ('צייכענונגען', 84),
#  ('ארום', 84),
#  ("ב'", 84),
#  ('מאריס', 83),
#  ('איבערזעצונג', 83),
#  ('יוגנט', 83),
#  ('בנימין', 83),
#  ('געראנגל', 83),
#  ('/חיים', 83),
#  ('צוריק', 82),
#  ('אנטאלאגיע', 82),
#  ('נאכט', 82),
#  ('שטערן', 81),
#  ('אמעריקא', 81),
#  ('צוזאמענגעשטעלט', 81),
#  ('אידען', 81),
#  ('נח', 81),
#  ('שטעטל', 81),
#  ('הקדמה', 81),
#  ('אלטע', 81),
#  ('רעוואלוציע', 81),
#  ('פסח', 80),
#  ('אויס', 80),
#  ('נ', 80),
#  ('ווען', 79),
#  ('מעשהלעך', 79),
#  ('הרב', 79),
#  ('דע', 79),
#  (':פון', 79),
#  ('פאעזיע', 78),
#  ('ווארשעווער', 77),
#  ('דערציילונגען,', 77),
#  ('דראמען', 77),
#  ('יואל', 76),
#  ('קליינע', 76),
#  ('טוב', 76),
#  ('שלום-עליכם', 76),
#  (':די', 76),
#  ('קארל', 75),
#  ('ארגענטינע', 75),
#  ('מאסקווע', 75),
#  ('אוצר', 74),
#  ('חלום', 74),
#  ('געשטאלטן', 74),
#  ('טויט', 74),
#  ('לייבוש', 74),
#  ('בלשון', 74),
#  ('פיער', 73),
#  ('הלל', 72),
#  ('גרויסע', 72),
#  ("/א'", 72),
#  ('שאטן', 71),
#  ('אפרים', 71),
#  ('כתבים', 71),
#  ('רחל', 71),
#  ('/שלום', 71),
#  ('דיכטער', 70),
#  ('ענגליש', 70),
#  ('ווילנער', 70),
#  ('מיטן', 70),
#  ('בית', 70),
#  ('געדאנקען', 70),
#  ('רעדעס', 70),
#  ('@פוילישע', 70),
#  ('צען', 69),
#  ('בעארבייט', 69),
#  ('ימים', 69),
#  ("ל'", 69),
#  ('/איבערזעצט', 69),
#  ('געזאנגען', 68),
#  ('אונזערע', 68),
#  ('אש', 68),
#  ("ר'", 68),
#  ('ארבייטער', 67),
#  ('מאקס', 67),
#  ('היינט', 67),
#  ('צייטען', 67),
#  ('פאריז', 67),
#  ('פוילישע', 67),
#  ('מאן', 67),
#  ('דרשות', 67),
#  ('פארלאג', 67),
#  (':דער', 67),
#  ('/שלמה', 67),
#  ('זאמלבוך', 66),
#  ('טראגעדיע', 66),
#  ('משלים', 66),
#  ('טריט', 66),
#  ('אילוסטראציעס', 66),
#  ('סאציאליזם', 66),
#  ('אויסגעוויילטע', 66),
#  ('רינג', 65),
#  ('מוזיק', 65),
#  ('איר', 65),
#  ('הונדערט', 65),
#  ('פרוי', 65),
#  ('/יידיש', 65),
#  ("/מ'", 65),
#  ('5', 64),
#  ('וואלף', 64),
#  ('קוואל', 64),
#  ('אף', 64),
#  ('לידער.', 64),
#  ("ד'", 64),
#  ('חיים,', 64),
#  ('יודישער', 63),
#  ('ווינט', 63),
#  ('אמת', 63),
#  ('תלמוד', 63),
#  ('בלוט', 62),
#  ('אקט', 62),
#  ('ביבליאגראפיע', 62),
#  ('שבת', 62),
#  ('נעכטן', 62),
#  ('שרה', 62),
#  ('גרויסער', 62),
#  ('יארק', 62),
#  ('ניו-יארק', 62),
#  ('א,', 62),
#  ('בענדער', 61),
#  ('הלוי', 61),
#  ('לשון', 61),
#  ('דייטש', 61),
#  ('יום', 61),
#  ('לעצטער', 61),
#  ('מדינת', 61),
#  ('זעקס', 61),
#  ('רייזען,', 61),
#  ('קינד', 60),
#  ('פרץ.', 60),
#  ('מענש', 60),
#  ('רבקה', 60),
#  ('יחיאל', 60),
#  ('נחום', 60),
#  ('יחזקאל', 60),
#  ('אונדזערע', 60),
#  ('אבא', 60),
#  ('מלכה', 60),
#  ('בענד', 60),
#  ('/לייב', 60),
#  ("/י'", 60),
#  ('דערציילונג', 59),
#  ('אסתר', 59),
#  ('יעפים', 59),
#  ('נביאים', 59),
#  ('בעל', 59),
#  ("ז'", 59),
#  ('אלמאנאך', 58),
#  ('שולן', 58),
#  ('צונויפגעשטעלט', 58),
#  ('רוסישער', 58),
#  ('ארץ-ישראל', 58),
#  (':(א', 58),
#  ('אונד', 57),
#  ('פאלקס', 57),
#  ('לעווין.', 57),
#  ('זייער', 57),
#  ('ח', 57),
#  ('/י.', 57),
#  ('/ישראל', 57),
#  ('פרעסע', 56),
#  ('פייער', 56),
#  ('אליין', 56),
#  ('דר.', 56),
#  ('לענדער', 56),
#  (':זיין', 56),
#  ('ניי', 55),
#  ('ייד', 55),
#  ('ערצעהלונג', 55),
#  ('באארבעט', 55),
#  ('פעטער', 55),
#  (':עסייען', 55),
#  ('געזעלשאפט', 54),
#  ('בילדער,', 54),
#  ('סקיצן', 54),
#  ('פנקס', 54),
#  ('יודל', 54),
#  ('האב', 54),
#  ('זיבן', 54),
#  ('ווילנע', 54),
#  ('מיכל', 54),
#  ('לעקסיקאן', 54),
#  ('טייטש', 54),
#  ('פנחס', 54),
#  ('קלמן', 54),
#  ('פונם', 54),
#  ('Jh.', 54),
#  ('/א.', 54),
#  ('ד', 54),
#  ('מאטעריאלן', 53),
#  ('י.ל.', 53),
#  ('נאוועלע', 53),
#  ('עלטסטע', 53),
#  ('דב', 53),
#  ('אויך', 53),
#  ('ברידער', 53),
#  ('הערש', 53),
#  ('חומשי', 53),
#  ('קליין', 53),
#  ('זינגען', 53),
#  ('יעקב,', 53),
#  ('/שמואל', 53),
#  ('גארדין,', 53),
#  ('ק.', 52),
#  ('וו.', 52),
#  ('זייט', 52),
#  ('אשר', 52),
#  ('מדרש', 52),
#  ('ישראל,', 52),
#  ('גורל', 52),
#  ('מארק.', 52),
#  ('אלעקסאנדער', 52),
#  ('גאט', 52),
#  ('תל-אביב', 52),
#  ('נאציאנאלע', 51),
#  ('ציון', 51),
#  ('מוטער', 51),
#  ('ראפאפארט.', 51),
#  ('טייל', 51),
#  ('מענשען', 51),
#  ('רפאל', 51),
#  ('חמשה', 51),
#  ('סאציאלע', 51),
#  ('עליכם.', 51),
#  ('פירוש', 51),
#  ('י,', 51),
#  ('אנטוויקלונג', 50),
#  ('אש.', 50),
#  ('כרעסטאמאטיע', 50),
#  ('נישט', 50),
#  ('ערשטן', 50),
#  ('מיכאל', 50),
#  ('כהן,', 50),
#  ('אויסגאבע', 50),
#  ('שטורעם', 50),
#  ('וועגנ', 50),
#  ('שמחה', 50),
#  ('אפאטאשו,', 50),
#  ('איד', 49),
#  ('פרילינג', 49),
#  ('מארקס', 49),
#  ('קריטיק', 49),
#  ('אויפשטאנד', 49),
#  ('עסייען,', 49),
#  ('פערל', 49),
#  ('אגדות', 49),
#  ('כל', 49),
#  ('גוט', 49),
#  ('צווייטער', 49),
#  ('טובים', 49),
#  ('זי', 49),
#  ('/מ.', 49),
#  ('נ&#039;', 49),
#  ('תל', 48),
#  ('משה,', 48),
#  ('ר.', 48),
#  ('פֿון', 48),
#  ('לכבוד', 48),
#  ('לערער', 48),
#  ('ווערטער', 48),
#  ('לערנען', 48),
#  ('תקופה', 48),
#  ('גלות', 48),
#  ('בילד', 48),
#  ('וו', 48),
#  ('אים', 47),
#  ('רייזען.', 47),
#  ('ליעבע', 47),
#  ('זיינען', 47),
#  ('בונד', 47),
#  ('נאטור', 47),
#  ('שווארץ.', 47),
#  ('באנד', 47),
#  ('ראובן', 47),
#  ('שפיל', 47),
#  ('אביב', 47),
#  ('ארטיקלען', 46),
#  ('רוסיש', 46),
#  ('חומש', 46),
#  ('גרשון', 46),
#  ('נשמה', 46),
#  ('סאוועטישע', 46),
#  ('רייזען', 46),
#  ('סוף', 46),
#  ('פערזן', 46),
#  ('ליבע', 46),
#  ('/אליעזר', 46),
#  ('זשיטלאווסקי,', 46),
#  ('אפהאנדלונגען', 45),
#  ('עברי', 45),
#  ('יענער', 45),
#  ('אייראפע', 45),
#  ('צייכנונגען', 45),
#  ('אלי', 45),
#  ('1', 45),
#  ('ס', 45),
#  ('לעווין,', 45),
#  ('ב,', 45),
#  ('מ,', 45),
#  ('ביידע', 44),
#  ('ליטעראטור,', 44),
#  ('קעגן', 44),
#  ('אויגן', 44),
#  ('בערל', 44),
#  ('יודיש', 44),
#  ('בין', 44),
#  ('יארצייט', 44),
#  ('הימלען', 44),
#  ('2', 44),
#  ('דניאל', 44),
#  ('הומאריסטישע', 44),
#  ('הימל', 44),
#  ('גאלדענע', 44),
#  ('אפהאנדלונג', 44),
#  ('ציוניזם', 44),
#  ("ה'", 44),
#  ('אמשטרדם', 44),
#  (':זכרונות', 44),
#  ('/מרדכי', 44),
#  ('/צונויפגעשטעלט', 44),
#  ('יובל', 43),
#  ('לערנבוך', 43),
#  ('קינסטלער', 43),
#  ('לענין', 43),
#  ('גארדין.', 43),
#  ('פעלקער', 43),
#  ('איבערלעבונגען', 43),
#  ('לוי', 43),
#  ('ליבשאפט', 43),
#  ('באלאדן', 43),
#  ('פרייד', 43),
#  ('חײם', 43),
#  ('/ל.', 43),
#  ("/ב'", 43),
#  ('זאָל', 43),
#  ('ביכער', 42),
#  ('דארף', 42),
#  ('מאת', 42),
#  ('ביבליאטעק', 42),
#  ('פראזע', 42),
#  ('ערב', 42),
#  ('ארבעט', 42),
#  ('אלחנן', 42),
#  ('הערמאן', 42),
#  ('פאררעדע', 42),
#  ('וואך', 42),
#  ('פרומקין.', 42),
#  ('יהודא', 42),
#  ('מחזור', 42),
#  ('בוענאס-איירעס', 42),
#  ('ג', 42),
#  ('גאלדבערג.', 41),
#  ('ווערטערבוך', 41),
#  ('עמיל', 41),
#  ('הענריק', 41),
#  ('כהן.', 41),
#  ('מעמוארן', 41),
#  ('ווערן', 41),
#  ('גאנץ', 41),
#  ('נפתלי', 41),
#  ('דערציילט', 41),
#  ('בארג', 41),
#  ('טאגבוך', 41),
#  ('שמועסן', 41),
#  ('מנהגים', 41),
#  ('פונעמ', 41),
#  ('קיפניס,', 41),
#  ('פראפעסאר', 41),
#  ('מרים', 40),
#  ('ג.', 40),
#  ('קאפלאן.', 40),
#  ('פיליפ', 40),
#  ('כהן', 40),
#  ('חנה', 40),
#  ('רעכט', 40),
#  ('משפחה', 40),
#  ('דערקלערונגען', 40),
#  (':מיט', 40),
#  ('טהעאטער', 40),
#  ('איירעס', 40),
#  ('גרעץ', 40),
#  ("פ'", 40),
#  ('אי', 40),
#  ('ל,', 40),
#  ('שריפטן.', 39),
#  ('מייזיל.', 39),
#  ('יונה', 39),
#  ('קורצע', 39),
#  ('לייענבוך', 39),
#  ('מעשות', 39),
#  ('גאס', 39),
#  ('שמשון', 39),
#  ('מאל', 39),
#  ('שפיגל', 39),
#  ('גאנג', 39),
#  ('באריכט', 38),
#  ('אלגעמיינע', 38),
#  ('שטילע', 38),
#  ('בײ', 38),
#  ('ײדן', 38),
#  ('שם', 38),
#  ('שירים', 38),
#  ('נתן', 38),
#  ('אפן', 38),
#  ('פלאמען', 38),
#  ('דערציילן', 38),
#  ('בלעטלעך', 38),
#  ('פאליטישע', 38),
#  ('הילע', 38),
#  ('רוסישע', 38),
#  ('יאסל', 38),
#  ('לערניאר', 38),
#  ('@געשיכטע', 38),
#  ('מוכר-ספרים', 38),
#  ('/פערפאסט', 38),
#  ('קאמיטעט', 37),
#  ('זשיטלאווסקי.', 37),
#  ('קעניג', 37),
#  ('אבן', 37),
#  ('געדאנק', 37),
#  ('הילף', 37),
#  ('קוועלען', 37),
#  ('ארויסגעגעבען', 37),
#  ('קעמפער', 37),
#  ('ישעיהו', 37),
#  ('מאני', 37),
#  ('טאלסטאי,', 37),
#  ('נאכן', 37),
#  ('נאטיצן', 37),
#  ('רויטע', 37),
#  ('אליצקי.', 37),
#  ('סעם', 37),
#  ('דוב', 37),
#  ('רב', 37),
#  ('פרייהייט', 37),
#  ('12', 37),
#  ('פראנצויזיש', 37),
#  ('פיל', 37),
#  ('וועלט-געשיכטע', 37),
#  ('ראזענפעלד,', 37),
#  ("/ה'", 37),
#  ('האָט', 37),
#  ('ש,', 37),
#  ('פראגמענטן', 36),
#  ('נאדיר.', 36),
#  ('לײב', 36),
#  ('זינגער.', 36),
#  ('יונג', 36),
#  ('הומאר', 36),
#  ('ישורין.', 36),
#  ('חסידות', 36),
#  ('דו', 36),
#  ('האבן', 36),
#  ('שאטנס', 36),
#  ('יודען', 36),
#  ('וואלד', 36),
#  ('דענקער', 36),
#  ('דיכטונג', 36),
#  ('הקודש', 36),
#  ('ברויט', 36),
#  ('מבול', 36),
#  ('איצק', 36),
#  ('פערפאסט', 35),
#  ('דערצײלונגען', 35),
#  ('פריי', 35),
#  ('דרוק', 35),
#  ('פארבאנד', 35),
#  ('צוגעגרייט', 35),
#  ('באלאדעס', 35),
#  ('בוים', 35),
#  ('קאפיטלען', 35),
#  ('גייט', 35),
#  ('געזאמלט', 35),
#  ('באמערקונגען', 35),
#  ('אייגענע', 35),
#  ('דאקטאר', 35),
#  ('/אהרן', 35),
#  (':(ראמאן)', 35),
#  ('גיו', 35),
#  ('יודישען', 34),
#  ('י.י.', 34),
#  ('ערציהונג', 34),
#  ('יונגע', 34),
#  ('יידישקייט', 34),
#  ('בראשית', 34),
#  ('of', 34),
#  ('זאמעלבוך', 34),
#  ('תלמוד,', 34),
#  ('זשול', 34),
#  ('מארריס', 34),
#  ('בעארבייטעט', 34),
#  ('דא', 34),
#  ('סדר', 34),
#  ('איינדרוקן', 34),
#  ('דערציילונגען.', 34),
#  ('געצייכנט', 34),
#  ('דאוויד', 34),
#  ('קאץ.', 34),
#  ('טרילאגיע', 34),
#  ('מדבר', 34),
#  ('פעלד', 34),
#  ('עקאנאמיע', 34),
#  ('לעבען,', 34),
#  ('חסידישע', 34),
#  ('זשאן', 34),
#  ('אונ׳', 34),
#  ("/ש'", 34),
#  ('/לעאן', 34),
#  ('/מאיר', 34),
#  ('אברהם,', 34),
#  ('געוועהלטע', 33),
#  ('גאלד', 33),
#  ('ספעקטאר.', 33),
#  ('עברית', 33),
#  ('פרידמאן.', 33),
#  ('ס.', 33),
#  ('יוגענד', 33),
#  ('ניגון', 33),
#  ('עמנואל', 33),
#  ('נאטע', 33),
#  ('סאציאלער', 33),
#  ('ראמאן.', 33),
#  ('מאטל', 33),
#  ('לעגענדע', 33),
#  ('קריג', 33),
#  ('אדם', 33),
#  ('מארק,', 33),
#  ('יצחק,', 33),
#  ('/רעדאגירט', 33),
#  ('פרעמדע', 32),
#  ('קאמוניסטישער', 32),
#  ('פארטיי', 32),
#  ('אב.', 32),
#  ('אבות', 32),
#  ('שיין', 32),
#  ('אריגינאל', 32),
#  ('הארץ', 32),
#  ('מחבר', 32),
#  ('ישוב', 32),
#  ('הירשביין.', 32),
#  ('פארטרעטן', 32),
#  ('פנים', 32),
#  ('אידישקייט', 32),
#  ('גליק', 32),
#  ('ארן', 32),
#  ('באלאדע', 32),
#  ('סאנעטן', 32),
#  ('קאברין.', 32),
#  ('יוביליי', 32),
#  ('25', 32),
#  ('קוואלן', 32),
#  ('שריפטשטעלער', 32),
#  ('קוויטקא,', 32),
#  ("ח'", 32),
#  ('/מיט', 32),
#  (':פאר', 32),
#  ('/ארויסגעגעבן', 32),
#  ("נ'", 32),
#  ('/פרץ', 32),
#  ('אױף', 31),
#  ('קאמעדיע', 31),
#  ('לעא', 31),
#  ('פראגע', 31),
#  ('בלומען', 31),
#  ('לעבן.', 31),
#  ('לעבן,', 31),
#  ('צוזאמענפאר', 31),
#  ('דאך', 31),
#  ('אפנ', 31),
#  ('יודא', 31),
#  ('ביאגראפישע', 31),
#  ('זכרון', 31),
#  ('זאב', 31),
#  ('ראזענפעלד.', 31),
#  ('געשריבן', 31),
#  ('ליטע', 31),
#  ('ישעיה', 31),
#  ('רעפארטאזשן', 31),
#  ('אורי', 31),
#  ('ווילדע', 31),
#  ('זיי', 31),
#  ('פערזענלעכקייטן', 31),
#  ('געזונט', 31),
#  ('דאן', 31),
#  ('הויף', 31),
#  ('מאקסים', 31),
#  ('וכתובים', 31),
#  ('זינגער,', 31),
#  ('שילדערונג', 31),
#  ('הירשביין,', 31),
#  ('קאהאן,', 31),
#  ('קען', 31),
#  ('/דער', 31),
#  ("/ל'", 31),
#  ('אַז', 31),
#  ('דוד,', 31),
#  ('1886-1954', 31),
#  ('לא', 30),
#  ('ארטור', 30),
#  ('פעלדער', 30),
#  ('געזאמעלט', 30),
#  ('קיפניס.', 30),
#  ('אנדענק', 30),
#  ('הערץ', 30),
#  ('חוה', 30),
#  ('ווערט', 30),
#  ('צדיק', 30),
#  ('איבערבליק', 30),
#  ('מאמרים', 30),
#  ('פעליעטאנען', 30),
#  ('אומקום', 30),
#  ('יענע', 30),
#  ('פארצייכענונגען', 30),
#  ('לובלין', 30),
#  ('ענגלאנד', 30),
#  ('בערג', 30),
#  ('מאמע', 30),
#  ('דיר', 30),
#  ('סקיצען', 30),
#  ('פילאזאפיע', 30),
#  ('טאלסטאי', 30),
#  ('/רעדאקטירט', 30),
#  ('/מאת', 30),
#  ('שלמה,', 30),
#  ('נאדיר,', 30),
#  ('גארקי,', 30),
#  ('גרעץ,', 30),
#  ('בערגעלסאן,', 30),
#  ('קאזלאווסקי.', 29),
#  ('פענצטער', 29),
#  ('זאק.', 29),
#  ('the', 29),
#  ('בעסטע', 29),
#  ('גייסט', 29),
#  ('מאדערנע', 29),
#  ('השנה', 29),
#  ('סאציאליסטישע', 29),
#  ('הגדה', 29),
#  ('מארגן', 29),
#  ('דברי', 29),
#  ('שטיין', 29),
#  ('כאים', 29),
#  ('צוועלף', 29),
#  ('פרויען', 29),
#  ('פאט.', 29),
#  ('אוקראינע', 29),
#  ('יהואש', 29),
#  ('סדרות', 29),
#  ('געשיכטע,', 29),
#  ('גרויס', 29),
#  ('/ש.', 29),
#  ('פראלאג', 29),
#  ('רעליגיאן', 29),
#  ('זענען', 29),
#  ('אפאריזמען', 29),
#  ('יסודות', 29),
#  ('הערמאלין.', 29),
#  ('וועלט-מלחמה', 29),
#  ('בו', 29),
#  ('/יהודה', 29),
#  (':פאעמע', 29),
#  (':היסטארישער', 29),
#  (':זאמלונג', 29),
#  (':ראמאן.', 29),
#  ('1865-1943', 29),
#  ('זשורנאל', 28),
#  ('הארבסט', 28),
#  ('ראזשאנסקי.', 28),
#  ('צ.', 28),
#  ('ערציילונגען', 28),
#  ('היינטיקער', 28),
#  ('קלאנגען', 28),
#  ('לאדזש', 28),
#  ('רעדאקטאר', 28),
#  ('קונטרס', 28),
#  ('רבינו', 28),
#  ('דרום', 28),
#  ('אלטן', 28),
#  ('עפיזאדן', 28),
#  ('צוקונפט', 28),
#  ('אב', 28),
#  ('שטודיעס', 28),
#  ('העלדן', 28),
#  ('וויליאם', 28),
#  ('שניאור', 28),
#  ('לעבנס', 28),
#  ('הכהן', 28),
#  ('מזרח', 28),
#  ('לייוויק', 28),
#  ('פאריזער', 28),
#  ('שיר', 28),
#  ('אוצרות', 28),
#  ('צווייטן', 28),
#  ('כותר', 28),
#  ('נוסף', 28),
#  ('זליגמן', 28),
#  ('ספעקטאר,', 28),
#  ('/זלמן', 28),
#  ('/ב.', 28),
#  ('/נחום', 28),
#  ('גוטמאן,', 28),
#  ('פאט,', 28),
#  ('בני', 27),
#  ('ע.', 27),
#  ('ביבלישע', 27),
#  ('נאוויק.', 27),
#  ('פרייע', 27),
#  ('פראקטישע', 27),
#  ('גראמאטיק', 27),
#  ('באריס', 27),
#  ('וויסנשאפט', 27),
#  ('אינסטיטוט', 27),
#  ('לאנדאן', 27),
#  ('עקאנאמישע', 27),
#  ('מייזיל,', 27),
#  ('נוסח', 27),
#  ('לאה', 27),
#  ...]

# %%
Counter(trns_tokens).most_common()
# Out:
# [('fun', 11014),
#  ('un', 8840),
#  (':', 6086),
#  ('der', 5966),
#  ('in', 5950),
#  ('di', 4900),
#  ('a', 4257),
#  ('/', 4232),
#  ('lider', 1984),
#  ('...', 1502),
#  ('roman', 1398),
#  (';', 1376),
#  ('far', 1252),
#  ('dos', 1129),
#  ('tsu', 975),
#  ('dertseylungen', 964),
#  ('lebn', 931),
#  ('yidishe', 789),
#  ('oyf', 782),
#  ('mayn', 738),
#  ('dem', 715),
#  ('zayn', 678),
#  ('miṭ', 637),
#  ('yidisher', 633),
#  ('geshikhṭe', 586),
#  ('ale', 572),
#  ('ṿerḳ', 561),
#  ('b.', 545),
#  ('=', 514),
#  ('yidn', 474),
#  ('tsum', 456),
#  ('bilder', 455),
#  ('a.', 443),
#  ('andere', 442),
#  ('yidishn', 439),
#  ('iz', 436),
#  ('y.', 435),
#  ('sholem', 433),
#  ('sefer', 432),
#  ('yor', 423),
#  ('eseyen', 414),
#  ('idishe', 406),
#  ('ṿegn', 404),
#  ('bukh', 399),
#  ('ben', 394),
#  ('zikhroynes̀', 390),
#  ('yidish', 384),
#  ('m.', 363),
#  ('biz', 360),
#  ('geḳlibene', 340),
#  ('dray', 339),
#  ('leben', 328),
#  ('an', 313),
#  ('isaac', 304),
#  ('leib,', 301),
#  ('iber', 294),
#  ('yitsḥaḳ', 291),
#  ('liṭeraṭur', 291),
#  ('poemes', 280),
#  ('bay', 279),
#  ('miṭ', 271),
#  ('zamlung', 262),
#  ('mayne', 254),
#  ('fir', 254),
#  ('mosheh', 254),
#  ('geshikhṭe', 254),
#  ('yosef', 251),
#  ('shrifṭen', 249),
#  ('peretz,', 248),
#  ('avraham', 245),
#  ('naye', 245),
#  ('idisher', 244),
#  ('ḳinder', 237),
#  ('the', 235),
#  ('david,', 235),
#  ('yorn', 231),
#  ('ṿelṭ', 227),
#  ('d.', 227),
#  ('of', 227),
#  ('ṿegn', 226),
#  ('shrifṭn', 224),
#  ('poyln', 223),
#  ('or', 223),
#  ('aleichem,', 221),
#  ('1859-1916', 220),
#  ('zikh', 219),
#  ('durkh', 212),
#  ('jacob,', 211),
#  ('h.', 208),
#  ('sh.', 208),
#  ('ikh', 208),
#  ('m,', 206),
#  ('l.', 205),
#  ('yudishe', 203),
#  ('oyfn', 197),
#  ('ṿos', 194),
#  ('nokh', 194),
#  ('unzer', 194),
#  ('shul', 189),
#  ('oder,', 187),
#  ('mir', 185),
#  ('shrayber', 182),
#  ('erd', 181),
#  ('tsayṭ', 180),
#  ('ertsehlungen', 180),
#  ('farn', 178),
#  ('heym', 178),
#  ('eyn', 177),
#  ('unṭer', 177),
#  ('yiśroel', 177),
#  ('1851', 177),
#  ('ḥayim', 176),
#  ('zayne', 176),
#  ('dor', 175),
#  ('drame', 175),
#  ('tsṿey', 173),
#  ('undzer', 172),
#  ('abraham', 172),
#  ('poeme', 171),
#  ('gezamelṭe', 171),
#  ('2-1915', 171),
#  ('idish', 169),
#  ('ameriḳe', 169),
#  ('a,', 169),
#  ('folḳ', 167),
#  ('tsṿishn', 165),
#  ('perets', 163),
#  ('lid', 163),
#  ('abraham,', 163),
#  ('poemen', 161),
#  ('n.', 160),
#  ('ḳinder', 160),
#  ('oder', 158),
#  ('[fun]', 157),
#  ('daṿid', 156),
#  ('mendele', 155),
#  ('land', 152),
#  ('ṿeg', 152),
#  ('david', 152),
#  ('rayze', 151),
#  ('shelomoh', 147),
#  ('baym', 142),
#  ('zun', 140),
#  ('lider,', 140),
#  ('azoy', 140),
#  ('mit', 138),
#  ('iberzetsṭ', 136),
#  ('ṿi', 136),
#  ('funem', 136),
#  ('gezamlṭe', 135),
#  ('asch,', 135),
#  ('geḳlibene', 134),
#  ('ṭeg', 133),
#  ('shemuʾel', 132),
#  ('joseph,', 132),
#  ('aḳṭen', 131),
#  ('yaʻaḳov', 131),
#  ('gezang', 130),
#  ('-', 130),
#  ('shel', 129),
#  ('4', 129),
#  ('sholem,', 129),
#  ('z.', 128),
#  ('1880-1957', 128),
#  ('yehudah', 126),
#  ('r.', 125),
#  ('af', 125),
#  ('israel', 125),
#  ('farlag', 125),
#  ('ṿelṭ', 124),
#  ('b,', 124),
#  ('s.', 123),
#  ('toyre', 123),
#  ('zamlbukh', 122),
#  ('nayer', 121),
#  ('finf', 121),
#  ('dertseylungen,', 120),
#  ('shprakh', 119),
#  ('ṿos', 119),
#  ('aharon', 118),
#  ('idishn', 118),
#  ('menṭsh', 117),
#  ('geṭo', 115),
#  ('doyres̀', 114),
#  ('redaḳtsye', 113),
#  ('rusland', 113),
#  ('jacob', 113),
#  ('mokher', 113),
#  ('joseph', 112),
#  ('ṭeaṭer', 111),
#  ('likhṭ', 111),
#  ('drama', 110),
#  ('shafn', 109),
#  ('idn', 109),
#  ('l,', 108),
#  ('er', 107),
#  ('liṭerarishe', 106),
#  ('seyfer', 106),
#  ('yiśroel', 105),
#  ('problemen', 104),
#  ('amol', 103),
#  ('und', 103),
#  ('es', 102),
#  ('ashkenaz', 102),
#  ('j.', 101),
#  ('aḳṭen', 101),
#  ('chaim,', 101),
#  ('ḳamf', 100),
#  ('dramen', 100),
#  ('men', 99),
#  ('idishen', 99),
#  ('tsṿey', 99),
#  ('ṿerḳ', 98),
#  ('s,', 98),
#  ('folḳ', 97),
#  ('dertseylung', 96),
#  ('tsṿishn', 96),
#  ('m', 96),
#  ('erets', 95),
#  ('arum', 95),
#  ('h,', 95),
#  ('hoṭ', 94),
#  ('lieder', 94),
#  ('yohr', 94),
#  ('isaac,', 93),
#  ('ameriḳe', 93),
#  ('ṿorṭ', 92),
#  ('anṭologye', 92),
#  ('noṿeln', 92),
#  ('and', 91),
#  ('leyb', 91),
#  ('hoyz', 91),
#  ('yam', 91),
#  ('gerangl', 91),
#  ('tsayṭ', 91),
#  ('1899-', 91),
#  ('ṿegen', 90),
#  ('arbeṭer', 90),
#  ('nit', 90),
#  ('l', 90),
#  ('bleṭer', 89),
#  ('3', 89),
#  ('moshe', 89),
#  ('poezye', 89),
#  ('shrifṭn', 89),
#  ('biografye', 89),
#  ('afn', 88),
#  ('lider.', 88),
#  ('liṭeraṭur', 88),
#  ('shrifṭen', 87),
#  ('roman.', 87),
#  ('hisṭorisher', 87),
#  ('yiśraʾel', 87),
#  ('redes', 87),
#  ('tsevi', 86),
#  ('1906-', 86),
#  ('sefarim,', 86),
#  ('1835-1917', 86),
#  ('mayśes̀', 85),
#  ('simon,', 85),
#  ('ṿeg', 84),
#  ('aḳṭn', 83),
#  ('menṭshn', 82),
#  ('samuel', 82),
#  ('avrom', 81),
#  ('ertsehlung', 81),
#  ('lernbukh', 80),
#  ('ḳulṭur', 80),
#  ('on', 80),
#  ('nyu', 80),
#  ('ṭeg', 80),
#  ('ber', 80),
#  ('froy', 80),
#  ('unzere', 79),
#  ('eseyen,', 79),
#  ('mesholim', 79),
#  ('ṿi', 79),
#  ('hirsh', 78),
#  ('ershṭe', 78),
#  ('hisṭorishe', 78),
#  ('yidnṭum', 78),
#  ('ṿarshe', 78),
#  ('tsayṭn', 78),
#  ('undzere', 78),
#  ('ʿim', 78),
#  ('yudisher', 77),
#  ('almanakh', 77),
#  ('ṭog', 77),
#  ('bender', 77),
#  ('heinrich,', 77),
#  ('zalman', 76),
#  ('geṿen', 76),
#  ('1891-', 76),
#  ('solomon,', 76),
#  ('loyṭ', 75),
#  ('im', 74),
#  ('dr.', 74),
#  ('y.l.', 74),
#  ('man', 74),
#  ('j,', 74),
#  ('aroysgegebn', 73),
#  ('dertseylungen.', 73),
#  ('groyse', 73),
#  ('yaʿaḳov', 73),
#  ('reisen,', 73),
#  ('i', 72),
#  ('redaḳṭirṭ', 72),
#  ('oys', 72),
#  ('araynfir', 72),
#  ('yid', 71),
#  ('iden', 71),
#  ('ir', 71),
#  ('oytser', 71),
#  ('israel,', 71),
#  ('bar', 70),
#  ('ḥ.', 70),
#  ('gezangen', 70),
#  ('fier', 70),
#  ('mordekhai', 70),
#  ('yiddish', 70),
#  ('briṿ', 70),
#  ('1865-1943', 70),
#  ('meir,', 70),
#  ('by', 69),
#  ('nyu-yorḳ', 69),
#  ('pariz', 69),
#  ('de', 68),
#  ('yorhunderṭ', 68),
#  ('bi-leshon', 68),
#  ('prese', 67),
#  ('poylishe', 67),
#  ('for', 66),
#  ('dramaṭishe', 66),
#  ('zibn', 66),
#  ('zol', 66),
#  ('noṿeln', 66),
#  ('dov', 66),
#  ('talmud', 66),
#  ('menṭsh', 66),
#  ('graetz,', 66),
#  ('zeyer', 65),
#  ('moyshe', 65),
#  ('mayselekh', 65),
#  ('zingen', 65),
#  ('samuel,', 65),
#  ('bibliografye', 64),
#  ('ash', 64),
#  ('ḥurbn', 64),
#  ('nay', 64),
#  ('shmuel', 64),
#  ('zhitlowsky,', 64),
#  ('1817-1891', 64),
#  ('tsen', 63),
#  ('shṭoṭ', 63),
#  ('rozshansḳi.', 63),
#  ('naḥman', 63),
#  ('groyser', 63),
#  ('i.', 63),
#  ('milḥome', 63),
#  ('1876-1953', 63),
#  ('itzik,', 63),
#  ('fon', 62),
#  ('shalom', 62),
#  ('tsuzamengeshṭelṭ', 62),
#  ('mensh', 62),
#  ('torah', 62),
#  ('baṿegung', 62),
#  ('shpil', 62),
#  ('chaim', 62),
#  ('gordin,', 62),
#  ('aḳṭn', 62),
#  ('1908-', 62),
#  ('1913-', 62),
#  ('ershṭer', 61),
#  ('hob', 61),
#  ('aleykhem', 61),
#  ('emes̀', 61),
#  ('fayer', 61),
#  ('aryeh', 61),
#  ('tel-aviv', 61),
#  ('1895-', 61),
#  ('ring', 60),
#  ('geshikhte', 60),
#  ('vi', 60),
#  ('perl', 60),
#  ('mosḳṿe', 60),
#  ('lender', 60),
#  ('ḳunsṭ', 59),
#  ('bilder,', 59),
#  ('leon', 59),
#  ('tsuriḳ', 59),
#  ('yehuda', 59),
#  ('s', 58),
#  ('mayśelekh', 58),
#  ('medines̀', 58),
#  ('oysgeṿeylṭe', 58),
#  ('mark,', 58),
#  ('ḳamf', 58),
#  ('geṭo', 58),
#  ('5', 57),
#  ('morris', 57),
#  ('tsvey', 57),
#  ('brider', 57),
#  ('rebe', 57),
#  ('hersh', 57),
#  ('reb', 57),
#  ('jewish', 56),
#  ('niṭ', 56),
#  ('meʾir', 56),
#  ('shuln', 56),
#  ('ṿarsheṿer', 56),
#  ('kol', 56),
#  ('ameriḳaner', 56),
#  ('alṭe', 56),
#  ('band', 56),
#  ('zi', 56),
#  ('english', 55),
#  ('friling', 55),
#  ('f.', 55),
#  ('memuarn', 55),
#  ('eliezer', 55),
#  ('zikhroynes', 55),
#  ('leḳsiḳon', 55),
#  ('eliyahu', 55),
#  ('aaron', 55),
#  ('1905-', 55),
#  ('redagirṭ', 54),
#  ('geshṭalṭn', 54),
#  ('shṭeṭl', 54),
#  ('argenṭine', 54),
#  ('shlomo', 54),
#  ('agodes̀', 54),
#  ('meir', 54),
#  ('ṭeyln', 54),
#  ('rusisher', 54),
#  ('menṭshn', 54),
#  ('jh.', 54),
#  ('leon,', 54),
#  ('morris,', 54),
#  ('lenin', 53),
#  ('tsunoyfgeshṭelṭ', 53),
#  ('zamelbukh', 53),
#  ('binyamin', 53),
#  ('ershṭe', 53),
#  ('ferzn', 53),
#  ('fartseykhenungen', 53),
#  ('2', 53),
#  ('kvitko,', 53),
#  ('amśṭerdam', 53),
#  ('1', 53),
#  ('opatoshu,', 53),
#  ('letsṭe', 52),
#  ('ophandlungen', 52),
#  ('iberzetsṭ', 52),
#  ('p.', 52),
#  ('ṿilner', 52),
#  ('oykh', 52),
#  ('hobn', 52),
#  ('shmuesn', 52),
#  ('goyrl', 52),
#  ('yerusholayim', 52),
#  ('gedanḳen', 52),
#  ('mendl', 52),
#  ('libe', 52),
#  ('leib', 52),
#  ('hunderṭ', 52),
#  ('nakhṭ', 52),
#  ('funm', 52),
#  ('lernyor', 52),
#  ('aaron,', 52),
#  ('zaynen', 51),
#  ('haynṭ', 51),
#  ('gants', 51),
#  ('noṿele', 51),
#  ('unṭer', 51),
#  ('sotsyalizm', 51),
#  ('1886-1954', 51),
#  ('aleyn', 50),
#  ('hoṭ', 50),
#  ('bild', 50),
#  ('tsayṭen', 50),
#  ('hirschbein,', 50),
#  ('moses', 50),
#  ('likhṭ', 50),
#  ('?', 50),
#  ('liebe', 49),
#  ('oygn', 49),
#  ('proze', 49),
#  ('zikhroynes̀,', 49),
#  ('y', 49),
#  ('yener', 49),
#  ('[microform]', 49),
#  ('iberlebungen', 49),
#  ('ṿelṭ-geshikhṭe', 49),
#  ('droshes̀', 49),
#  ('hisṭorisher', 49),
#  ('1893-', 49),
#  ('gezamelṭe', 48),
#  ('id', 48),
#  ('marḳ', 48),
#  ('moshe,', 48),
#  ('noaḥ', 48),
#  ('miṭn', 48),
#  ('ḳleyne', 48),
#  ('yugnṭ', 48),
#  ('menshen', 48),
#  ('arbeṭer', 48),
#  ('goldene', 48),
#  ('yorḳ', 48),
#  ('solomon', 48),
#  ('ṿegen', 48),
#  ('ʿal', 48),
#  ('leo,', 48),
#  ('alṭer', 47),
#  ('shoṭn', 47),
#  ('leyenbukh', 47),
#  ('natsyonale', 47),
#  ('baladn', 47),
#  ('yuden', 47),
#  ('himlen', 47),
#  ('himl', 47),
#  ('freyd', 47),
#  ('buenos', 47),
#  ('keyn', 47),
#  ('mordecai,', 47),
#  ('zalman,', 47),
#  ('1902-', 47),
#  ('shṭern', 46),
#  ('ameriḳa', 46),
#  ('[pseud.]', 46),
#  ('b', 46),
#  ('al', 46),
#  ('sotsyale', 46),
#  ('z,', 46),
#  ('liṭerarishe', 46),
#  ('1890-1952', 46),
#  ('beyde', 45),
#  ('iberzetsung', 45),
#  ('ertseylungen', 45),
#  ('oysgabe', 45),
#  ('ṭoyṭ', 45),
#  ('forṿorṭ', 45),
#  ('ṿilne', 45),
#  ('gas', 45),
#  ('dertseyln', 45),
#  ('lernen', 45),
#  ('rabi', 45),
#  ('ks̀ovim', 45),
#  ('shpigl', 45),
#  ('ṭriṭ', 45),
#  ('barg', 45),
#  ('profesor', 45),
#  ('1880-1948', 45),
#  ('1912-', 45),
#  ('dubnow,', 45),
#  ('1860-1941', 45),
#  ('1904-', 45),
#  ('pesaḥ', 44),
#  ('ṿen', 44),
#  ('g.', 44),
#  ('ḳṿal', 44),
#  ('menaḥem', 44),
#  ('bet', 44),
#  ('nachman,', 44),
#  ('1898-', 44),
#  ('yerushalayim', 43),
#  ('bikher', 43),
#  ('dikhṭer', 43),
#  ('shem', 43),
#  ('mayśe', 43),
#  ('ṿinṭ', 43),
#  ('fragmenṭn', 43),
#  ('roman,', 43),
#  ('humor', 43),
#  ('epizodn', 43),
#  ('ḥolem', 43),
#  ('shabes̀', 43),
#  ('itsiḳ', 43),
#  ('mordecai', 43),
#  ('mosheh,', 43),
#  ('kipnis,', 43),
#  ('bergelson,', 43),
#  ('ḳeyn', 42),
#  ('bund', 42),
#  ('hot', 42),
#  ('gang', 42),
#  ('ophandlung', 42),
#  ('eygene', 42),
#  ('sof', 42),
#  ('ershṭer', 42),
#  ('steinberg,', 42),
#  ('ṭragedye', 41),
#  ('shirim', 41),
#  ('moderne', 41),
#  ('mol', 41),
#  ('flamen', 41),
#  ('goles̀', 41),
#  ('ḥumshe', 41),
#  ('shṭoṭ', 41),
#  ('mayse', 41),
#  ('hisṭorishe', 41),
#  ('ṭog', 41),
#  ('az', 41),
#  ('eliezer,', 41),
#  ('yoyvl', 40),
#  ('algemeyne', 40),
#  ('ilusṭrirṭ', 40),
#  ('harts', 40),
#  ('lekoved', 40),
#  ('ṿorṭ', 40),
#  ('zalmen', 40),
#  ('elṭsṭe', 40),
#  ('legende', 40),
#  ('nekhṭn', 40),
#  ('yisroel', 40),
#  ('leybush', 40),
#  ('bin', 40),
#  ('fil', 40),
#  ('midber', 40),
#  ('bend', 40),
#  ('yidish,', 39),
#  ('liṭeraṭur,', 39),
#  ('fremde', 39),
#  ('gold', 39),
#  ('bluṭ', 39),
#  ('doṿid', 39),
#  ('ester', 39),
#  ('erev', 39),
#  ('arn', 39),
#  ('talmud,', 39),
#  ('nokhn', 39),
#  ('mabl', 39),
#  ('esey', 39),
#  ('anṭologye', 39),
#  ('reṿolutsye', 39),
#  ('ha-ḳodesh', 39),
#  ('tsienizm', 39),
#  ('@poylishe', 39),
#  ('singer,', 39),
#  ('mayśes̀', 39),
#  ('moishe,', 39),
#  ('tolstoy,', 39),
#  ('1909-', 39),
#  ('ḳind', 38),
#  ('pinḳes', 38),
#  ('yunge', 38),
#  ('yung', 38),
#  ('lerer', 38),
#  ('mani', 38),
#  ('eyrope', 38),
#  ('balade', 38),
#  ('neshome', 38),
#  ('zeḳs', 38),
#  ('ḥamishah', 38),
#  ('rusishe', 38),
#  ('khresṭomaṭye', 38),
#  ('ṭeaṭer', 38),
#  ('maḥzor', 38),
#  ('n', 38),
#  ('ḥayim,', 38),
#  ('hilel', 37),
#  ('meyer', 37),
#  ('hilf', 37),
#  ('froyen', 37),
#  ('niṭ', 37),
#  ('balades', 37),
#  ('v.', 37),
#  ('yortsayṭ', 37),
#  ('england', 37),
#  ('feld', 37),
#  ('don', 37),
#  ('parizer', 37),
#  ('@geshikhṭe', 37),
#  ('nadir,', 37),
#  ('gezamlṭe', 37),
#  ('yaaḳov', 37),
#  ('1884-1952', 37),
#  ('zshurnal', 36),
#  ('felder', 36),
#  ('ḳriṭiḳ', 36),
#  ('boris', 36),
#  ('du', 36),
#  ('mayzel,', 36),
#  ('zayṭ', 36),
#  ('boym', 36),
#  ('ḳleyn', 36),
#  ('humorisṭishe', 36),
#  ('arṭiḳlen', 36),
#  ('25', 36),
#  ('perush', 36),
#  ('ṭayṭsh', 36),
#  ('vladimir', 36),
#  ('ṭeyl', 36),
#  ('segal,', 36),
#  ('h', 36),
#  ('1910-', 36),
#  ('y,', 36),
#  ('melech,', 36),
#  ('1886-', 36),
#  ('1887-1961', 36),
#  ('ershṭn', 35),
#  ('sforim', 35),
#  ('daṿid', 35),
#  ('die', 35),
#  ('farband', 35),
#  ('shayn', 35),
#  ('leben,', 35),
#  ('yingl', 35),
#  ('goṭ', 35),
#  ('adam', 35),
#  ('stsenes', 35),
#  ('geṿen', 35),
#  ('minhogim', 35),
#  ('grets', 35),
#  ('1884-1958', 35),
#  ('verne,', 35),
#  ('jules,', 35),
#  ('1828-1905', 35),
#  ('y.y.', 34),
#  ('moris', 34),
#  ('heymishe', 34),
#  ('frage', 34),
#  ('blumen', 34),
#  ('berl', 34),
#  ('vos', 34),
#  ('baginen', 34),
#  ('arbeṭ', 34),
#  ('ḳapiṭlen', 34),
#  ('ṭheaṭer', 34),
#  ('groys', 34),
#  ('--', 34),
#  ('oyfshṭand', 34),
#  ('yene', 34),
#  ('shilderung', 34),
#  ('shimon', 34),
#  ('aba', 34),
#  ('dikhṭung', 34),
#  ('englisher', 34),
#  ('loyṭ', 34),
#  ('hoyf', 34),
#  ('ṭeyln', 34),
#  ('noṿele', 34),
#  ('mayśelekh', 34),
#  ('de,', 34),
#  ('gorky,', 34),
#  ('1828-1910', 34),
#  ('tel', 33),
#  ('e.', 33),
#  ('book', 33),
#  ('aḳṭ', 33),
#  ('lebn,', 33),
#  ('ha-leṿi', 33),
#  ('yugend', 33),
#  ('aleksander', 33),
#  ('nigunim', 33),
#  ('seder', 33),
#  ('yom', 33),
#  ('morgn', 33),
#  ('als', 33),
#  ('heldn', 33),
#  ('ashkenazi', 33),
#  ('gezamlṭ', 33),
#  ('ṭrilogye', 33),
#  ('yubiley', 33),
#  ('yidishen', 33),
#  ('ihr', 33),
#  ('dramaṭishe', 33),
#  ('..', 33),
#  ('1853-1909', 33),
#  ('1887-1964', 33),
#  ('avraham,', 33),
#  ('yudishen', 32),
#  ('nishṭ', 32),
#  ('yoysef', 32),
#  ('yitsḥaḳ', 32),
#  ('ibergezetsṭ', 32),
#  ('ṭov', 32),
#  ('dakh', 32),
#  ('ṿerṭer', 32),
#  ('alexander', 32),
#  ('biblioṭeḳ', 32),
#  ('folḳs', 32),
#  ('letsṭer', 32),
#  ('von', 32),
#  ('fraye', 32),
#  ('mame', 32),
#  ('dir', 32),
#  ('12', 32),
#  ('bazukh', 32),
#  ('soṿeṭishe', 32),
#  ('prolog', 32),
#  ('ḥayyim', 32),
#  ('redner', 32),
#  ('ameriḳaner', 32),
#  ('revolutsye', 32),
#  ('ḳleyne', 32),
#  ('mayśe', 32),
#  ('tsayṭn', 32),
#  ('i,', 32),
#  ('1889-', 32),
#  ('f,', 32),
#  ('1896-1974', 32),
#  ('sḳitsn', 31),
#  ('ṿolf', 31),
#  ('ḳegn', 31),
#  ('tsuzamenfor', 31),
#  ('perushim', 31),
#  ('shriften', 31),
#  ('ḳ.', 31),
#  ('naṭur', 31),
#  ('noṭitsn', 31),
#  ('tsṿeyṭer', 31),
#  ('lublin', 31),
#  ('fablen', 31),
#  ('ṿunder', 31),
#  ('dorf', 31),
#  ('gloybn', 31),
#  ('yesoydes̀', 31),
#  ('buenos-ayres', 31),
#  ('farshidene', 31),
#  ('zey', 31),
#  ('erinerungen', 31),
#  ('sholem-aleykhem', 31),
#  ('zvi', 31),
#  ('mordechai', 31),
#  ('benjamin', 31),
#  ('shṭeṭl', 31),
#  ('ameriḳa', 31),
#  ('1885-1943', 31),
#  ('joel,', 31),
#  ('pinski,', 31),
#  ('1907-', 31),
#  ('yaaḳov,', 31),
#  ('sh,', 31),
#  ('1957', 30),
#  ('biblishe', 30),
#  ('ayn', 30),
#  ('tsugegreyṭ', 30),
#  ('moysheh', 30),
#  ('yede', 30),
#  ('lodzsh', 30),
#  ('asher', 30),
#  ('letsṭe', 30),
#  ('shene', 30),
#  ('ḳulṭur', 30),
#  ('herman', 30),
#  ('gezelshafṭ', 30),
#  ('lebns', 30),
#  ('ponem', 30),
#  ('bleṭlekh', 30),
#  ('max', 30),
#  ('breyshes̀', 30),
#  ('yorhunderṭ', 30),
#  ('ilusṭratsyes', 30),
#  ('drames', 30),
#  ('moral', 30),
#  ('la', 30),
#  ('meylekh', 30),
#  ('filozofye', 30),
#  ('leivick,', 30),
#  ('ṿen', 30),
#  ('katz,', 30),
#  ('golomb,', 30),
#  ('milḥome', 30),
#  ('maksim,', 30),
#  ('1868-1936', 30),
#  ('itzhak,', 30),
#  ('1914-', 30),
#  ('alexander,', 30),
#  ('1892-', 30),
#  ('dertseylṭ', 29),
#  ('bearbeyṭ', 29),
#  ('fray', 29),
#  ('pyese', 29),
#  ('moykher', 29),
#  ('muṭer', 29),
#  ('to', 29),
#  ('cohen,', 29),
#  ('nign', 29),
#  ('rambam', 29),
#  ('yerushe', 29),
#  ('zeyere', 29),
#  ('gershon', 29),
#  ('alts', 29),
#  ('heymland', 29),
#  ('umḳum', 29),
#  ('mikhail', 29),
#  ('perzenlekhe', 29),
#  ('ṭogbukh', 29),
#  ("fun'm", 29),
#  ('opshatsungen', 29),
#  ('do', 29),
#  ('legendes', 29),
#  ('felḳer', 29),
#  ('yehoshua', 29),
#  ('un.', 29),
#  ('judah', 29),
#  ('u-khetuvim', 29),
#  ('yiśraʼel', 29),
#  ('nakhṭ', 29),
#  ('ṿarsheṿer', 29),
#  ('gedanḳen', 29),
#  ('schwartz,', 29),
#  ('d,', 29),
#  ('zinberg,', 29),
#  ('1873-1938', 29),
#  ('barikhṭ', 28),
#  ('ferfasṭ', 28),
#  ('ṿerṭerbukh', 28),
#  ('ḳarl', 28),
#  ('fragn', 28),
#  ('ibn', 28),
#  ('gezamelṭ', 28),
#  ('gedanḳ', 28),
#  ('london', 28),
#  ('alef', 28),
#  ('porṭreṭn', 28),
#  ('yuda', 28),
#  ('rabenu', 28),
#  ('bo', 28),
#  ('nayem', 28),
#  ('bilder.', 28),
#  ('tanakh,', 28),
#  ('doḳṭor', 28),
#  ('rand', 28),
#  ('dayn', 28),
#  ('familye', 28),
#  ('berg', 28),
#  ('medresh', 28),
#  ('kats', 28),
#  ('mishpoḥe', 28),
#  ('religyon', 28),
#  ('ha-shanah', 28),
#  ('shapiro,', 28),
#  ('yugnṭ', 28),
#  ('aires', 28),
#  ('peretz', 28),
#  ('shleṿin,', 28),
#  ('zeligman', 28),
#  ('ḳṿelen', 28),
#  ('ephraim', 28),
#  ('ṭoyṭ', 28),
#  ('erts', 28),
#  ('bleṭer', 28),
#  ('miṭn', 28),
#  ('zusman,', 28),
#  ('1896', 28),
#  ('spector,', 28),
#  ('1887-1966', 28),
#  ('1872-1959', 28),
#  ('g', 28),
#  ('me-et', 27),
#  ('barukh', 27),
#  ('yishev', 27),
#  ('o,', 27),
#  ('ʻal', 27),
#  ('yefim', 27),
#  ('inem', 27),
#  ('ḳurtse', 27),
#  ('prints', 27),
#  ('ahin', 27),
#  ('lili', 27),
#  ('shṭurem', 27),
#  ('lev', 27),
#  ('erets-yiśroel', 27),
#  ('monologn', 27),
#  ('mames', 27),
#  ('derḳlerungen', 27),
#  ('hemshekh', 27),
#  ('reyzen', 27),
#  ('bam', 27),
#  ('mener', 27),
#  ('arbeyṭer', 27),
#  ('ḳunsṭ', 27),
#  ('haynṭtsayṭiḳer', 27),
#  ('berger,', 27),
#  ('weinper,', 27),
#  ('aḳṭ', 27),
#  ('khresṭomaṭye', 27),
#  ('shoṭn', 27),
#  ('yeḥiel', 27),
#  ('segalowitch,', 27),
#  ('trunk,', 27),
#  ('ber,', 27),
#  ('saul,', 27),
#  ('henry,', 27),
#  ('bene', 26),
#  ('ash.', 26),
#  ('moderner', 26),
#  ('ḳomedye', 26),
#  ('dovid', 26),
#  ('ṭragedye', 26),
#  ('muziḳ', 26),
#  ('monografye', 26),
#  ('forsharbeṭn', 26),
#  ('bizn', 26),
#  ('gesheenishn', 26),
#  ('eliʻezer', 26),
#  ('yosl', 26),
#  ('berlin', 26),
#  ...]
